# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("mba-supplychain-ds1.csv")

# %%
df.head()
# Out:
#   Asset_ID           Location  Temperature  Vibration Last_Maintenance  \
# 0    A0001     Lake Davidland        32.34       3.99       2023-09-28
# 1    A0002        West Andrew        25.99       0.80       2023-04-26
# 2    A0003  New Kimberlyhaven        31.45       4.75       2024-12-23
# 3    A0004     Lake Cathyside        26.55       4.37       2024-10-22
# 4    A0005       South Justin        41.66       1.43       2024-08-17
#
#    Condition_Score  Resource_Utilization  Delivery_Efficiency  Downtime_Hours  \
# 0            67.39                 87.04                79.99            3.22
# 1            76.44                 81.06                92.07            2.89
# 2            61.85                 79.64                88.15            1.65
# 3            63.60                 79.88                72.63            8.07
# 4            61.62                 65.99                74.93            1.83
#
#   Inventory_Level  Logistics_Cost            Timestamp  \
# ...

# %%
df.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df.shape()
#
# TypeError: 'tuple' object is not callable

# %%
df.shape
# Out:
# (500, 13)

# %%
df.columns
# Out:
# Index(['Asset_ID', 'Location', 'Temperature', 'Vibration', 'Last_Maintenance',
#        'Condition_Score', 'Resource_Utilization', 'Delivery_Efficiency',
#        'Downtime_Hours', 'Inventory_Level', 'Logistics_Cost', 'Timestamp',
#        'SupplyChain_Efficiency_Label'],
#       dtype='str')

# %%
df.dtypes
# Out:
# Asset_ID                            str
# Location                            str
# Temperature                     float64
# Vibration                       float64
# Last_Maintenance                    str
# Condition_Score                 float64
# Resource_Utilization            float64
# Delivery_Efficiency             float64
# Downtime_Hours                  float64
# Inventory_Level                     str
# Logistics_Cost                  float64
# Timestamp                           str
# SupplyChain_Efficiency_Label      int64
# dtype: object

# %%
df.info
# Out:
# <bound method DataFrame.info of     Asset_ID              Location  Temperature  Vibration Last_Maintenance  \
# 0      A0001        Lake Davidland        32.34       3.99       2023-09-28
# 1      A0002           West Andrew        25.99       0.80       2023-04-26
# 2      A0003     New Kimberlyhaven        31.45       4.75       2024-12-23
# 3      A0004        Lake Cathyside        26.55       4.37       2024-10-22
# 4      A0005          South Justin        41.66       1.43       2024-08-17
# ..       ...                   ...          ...        ...              ...
# 495    A0496         Jenningsmouth        32.63       1.71       2024-09-28
# 496    A0497  North Jessicaborough        20.27       4.97       2023-07-25
# 497    A0498         Rodriguezfurt        37.53       3.61       2024-04-08
# 498    A0499       South Davidside        22.81       1.92       2024-05-01
# 499    A0500         Rodriguezland        38.75       1.85       2023-03-10
#
# ...

# %%
df.describe()
# Out:
#        Temperature   Vibration  Condition_Score  Resource_Utilization  \
# count   500.000000  500.000000       500.000000            500.000000
# mean     34.691180    2.508240        74.878440             77.879940
# std       8.791835    1.470361        14.134638             10.075504
# min      20.080000    0.000000        50.010000             60.010000
# 25%      26.687500    1.187500        62.687500             69.300000
# 50%      34.575000    2.480000        74.780000             78.555000
# 75%      42.275000    3.790000        87.357500             86.315000
# max      49.880000    4.990000        99.970000             94.960000
#
#        Delivery_Efficiency  Downtime_Hours  Logistics_Cost  \
# count           500.000000      500.000000      500.000000
# mean             84.165620        5.025020     4973.418100
# std               8.077746        2.961775     1183.049596
# min              70.020000        0.020000     3000.760000
# ...

# %%
df.isnull().sum()
# Out:
# Asset_ID                        0
# Location                        0
# Temperature                     0
# Vibration                       0
# Last_Maintenance                0
# Condition_Score                 0
# Resource_Utilization            0
# Delivery_Efficiency             0
# Downtime_Hours                  0
# Inventory_Level                 0
# Logistics_Cost                  0
# Timestamp                       0
# SupplyChain_Efficiency_Label    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
num=df.select_dtypes(include=np.number).columns

# %%
cat=df.select_dtypes(exclude=np.number).columns

# %%
print(num)
# Out:
# Index(['Temperature', 'Vibration', 'Condition_Score', 'Resource_Utilization',
#        'Delivery_Efficiency', 'Downtime_Hours', 'Logistics_Cost',
#        'SupplyChain_Efficiency_Label'],
#       dtype='str')

# %%
print(cat)
# Out:
# Index(['Asset_ID', 'Location', 'Last_Maintenance', 'Inventory_Level',
#        'Timestamp'],
#       dtype='str')

# %%
sns.distplot(df['Vibration'])
# Out:
# /var/folders/m9/0fgym0v92ml_n7jmhg844cpm0000gn/T/ipykernel_9383/3444245352.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Vibration'])
# <Axes: xlabel='Vibration', ylabel='Density'>

# %%
sns.distplot(df['SupplyChain_Efficiency_Label'])
# Out:
# /var/folders/m9/0fgym0v92ml_n7jmhg844cpm0000gn/T/ipykernel_9383/196938490.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['SupplyChain_Efficiency_Label'])
# <Axes: xlabel='SupplyChain_Efficiency_Label', ylabel='Density'>

# %%
sns.barplot(x='50',y='10',data=Condition_Score_df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 sns.barplot(x='50',y='10',data=Condition_Score_df)
#
# NameError: name 'Condition_Score_df' is not defined

# %%
sns.barplot(x='',y='',data=Condition_Score_df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 sns.barplot(x='',y='',data=Condition_Score_df)
#
# NameError: name 'Condition_Score_df' is not defined

# %%
sns.barplot(x='50',y='10',data=Condition_Score)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 sns.barplot(x='50',y='10',data=Condition_Score)
#
# NameError: name 'Condition_Score' is not defined

# %%
sns.barplot(x=df['Condition_Score'], y=df['Downtime_Hours'])
# Out:
# <Axes: xlabel='Condition_Score', ylabel='Downtime_Hours'>

# %%
sns.barplot(x=df['SupplyChain_Efficiency_Label'], y=df['Downtime_Hours'])
# Out:
# <Axes: xlabel='SupplyChain_Efficiency_Label', ylabel='Downtime_Hours'>

# %%
sns.boxplot(y=df[num[0]])
plt.show()

# %%
sns.scatterplot(x=df[num[0]],y=df[num[1]])
plt.show()

# %% [raw]
# plt.figure(figsize=(12,6))
# sns.heatmap(df[num].corr(),annot=True)
# plt.show()

# %%
plt.figure(figsize=(12,6))
sns.heatmap(df[num].corr(),annot=True)
plt.show()
